# %%
import data_load as dl
import dataset_creator as dc
import models
import warnings; warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import keras
import numpy as np
import time

# %matplotlib inline

# %%
path = r"C:\Users\Patrick\Datasets\sr\SR"
trial_paths = dl.combine_data(path)
trials = dl.generate_trial_objects(trial_paths)
processed_trials = dl.process_trial_data(trials)

# %%
[X_train, y_train, X_test, y_test] = dc.generate_dataset(processed_trials)

# %%
# for layer in deep_fcn.layers:
#     print(layer.output_shape)

# %%
deep_fcn = models.deep_FCN()

# %%
# Out:
# 0.06130330654341551

# %%
deep_fcn.fit(X_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 7839/7839 [==============================] - 517s 66ms/step - loss: 0.3287 - mean_squared_error: 0.3287
# Epoch 2/500
# 7839/7839 [==============================] - 528s 67ms/step - loss: 0.2925 - mean_squared_error: 0.2925
# Epoch 3/500
# 7839/7839 [==============================] - 517s 66ms/step - loss: 0.2679 - mean_squared_error: 0.2679
# Epoch 4/500
# 7839/7839 [==============================] - 519s 66ms/step - loss: 0.2395 - mean_squared_error: 0.2395
# Epoch 5/500
# 7839/7839 [==============================] - 514s 66ms/step - loss: 0.2166 - mean_squared_error: 0.2166
# Epoch 6/500
# 7839/7839 [==============================] - 508s 65ms/step - loss: 0.1955 - mean_squared_error: 0.1955
# Epoch 7/500
# 7839/7839 [==============================] - 506s 65ms/step - loss: 0.1765 - mean_squared_error: 0.1765
# Epoch 8/500
# 7839/7839 [==============================] - 508s 65ms/step - loss: 0.1563 - mean_squared_error: 0.1563
# Epoch 9/500
# ...

# %%
y_preds = deep_fcn.predict(X_train[0:20])
y_trues = y_train[0:20]

# %%
num = 12

y_true = np.squeeze(y_trues[num])
y_pred = np.squeeze(y_preds[num])

# %matplotlib inline
# %matplotlib notebook

fig = plt.figure()
plt.ion()

fig.show()
fig.canvas.draw()

for i in range(0,56):
    fig.clear()
    plt.plot(y_true[0:56])
    plt.plot(y_pred[0:i])
    #plt.xlim([0,60])
    #plt.ylim([1.8,2.3])
    fig.canvas.draw()
    time.sleep(0.001)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
from keras.models import load_model
model = load_model(r'C:\Users\Patrick\Downloads\trainedmodel.h5')

# %%
y_preds = model.predict(X_test)

# %%
y_preds = np.squeeze(y_preds)
y_true = np.squeeze(y_test)

# %%
plt.figure()
plt.plot(y_true[110])
plt.plot(y_preds[110])

# %%
plt.switch_backend("TkAgg")

# %%
# import numpy as np
# import time

# fig = plt.figure(figsize = (10,6))

# y1 = y_preds[3]
# y2 = y_true[3]

# for k in range(56):
#     plt.clf()
#     plt.plot(y_true)
#     plt.plot(y_preds[0:k])
#     fig.canvas.draw()
#     time.sleep(0.000001)
    
# plt.close(fig)
# %matplotlib qt

# %%
for i in range(100):
    plt.figure()
    plt.plot(y_preds[i])
    plt.plot(y_true[i])

# %%
X_train.shape

# %%
test

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import time

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

x = np.linspace(0,56,1)

def animate(i):
    for k in range(56):
            xar = [k]
            yar = [test[k]]
            xar.append(int(x))
            yar.append(int(y))
            time.sleep(1000)
    ax1.clear()
    ax1.plot(xar,yar)
ani = animation.FuncAnimation(fig, animate, interval=1000)
plt.show()

# %%
# %matplotlib inline
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import time

test = np.array([2.0494037, 2.0850868, 2.088936 , 2.073416 , 2.100016 , 2.118301 ,
       2.1274855, 2.1580164, 2.1478903, 2.1335151, 2.1109076, 2.094355 ,
       2.0892224, 2.087242 , 2.0755496, 2.0702643, 2.0735328, 2.0758095,
       2.0451622, 2.0582118, 2.0493422, 2.0259461, 1.9906698, 1.9687189,
       1.9648036, 1.9718157, 1.9752477, 1.9613723, 1.9348161, 1.9383566,
       1.9577693, 1.9521626, 1.9479659, 1.948521 , 1.9758601, 1.9890363,
       1.9977113, 1.9976138, 1.9825004, 2.0010438, 2.00609  , 2.011941 ,
       2.0259376, 2.0172827, 2.0203378, 2.0461144, 2.0637908, 2.0426462,
       2.058585 , 2.058635 , 2.0507689, 2.0461419, 2.040194 , 2.0350683,
       2.0469015, 2.0306516], dtype=float32)

x = np.linspace(0,56,1)
y = test

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

for i in range(0,56):
    ax.clear()
    ax.plot(test[i])
    fig.canvas.draw()
    time.sleep(0.5)
